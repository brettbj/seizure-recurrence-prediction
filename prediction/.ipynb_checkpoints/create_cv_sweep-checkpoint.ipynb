# %%
import os
labels = ['composite', 'proc_dates', 'note_drug_classes', 'neuro_note_count', 
          'status_epilepticus', 'total_inpatient', 'inpatient_seizure',
          'seizure_icd_days', 'seizure_visit_days', 'structured_drug_class']
print(len(labels))

output = ""
for l in labels:
    for split in range(5): 
        
        # not frozen
        results_path = f"./data/clean_model_{l}_0_{split}/config.json"
        print(results_path)
        if os.path.exists(results_path):
            print("Result already exists... skipping... remove to re-run") 
        else:
            output += f"python3 run_tf_training.py --label {l} --frozen 0 --cv_split {split} && \n"
        
        results_path = f"./data/clean_model_{l}_1_{split}/config.json"
        print(results_path)
        if os.path.exists(results_path):
            print("Result already exists... skipping... remove to re-run") 
        else:
            output += f"python3 run_tf_training.py --label {l} --frozen 1 --cv_split {split} && \n"
# Out:
# 10
# ./data/clean_model_composite_0_0/config.json
# Result already exists... skipping... remove to re-run
# ./data/clean_model_composite_1_0/config.json
# Result already exists... skipping... remove to re-run
# ./data/clean_model_composite_0_1/config.json
# Result already exists... skipping... remove to re-run
# ./data/clean_model_composite_1_1/config.json
# ./data/clean_model_composite_0_2/config.json
# Result already exists... skipping... remove to re-run
# ./data/clean_model_composite_1_2/config.json
# ./data/clean_model_composite_0_3/config.json
# ./data/clean_model_composite_1_3/config.json
# ./data/clean_model_composite_0_4/config.json
# ./data/clean_model_composite_1_4/config.json
# ./data/clean_model_proc_dates_0_0/config.json
# ./data/clean_model_proc_dates_1_0/config.json
# ./data/clean_model_proc_dates_0_1/config.json
# ./data/clean_model_proc_dates_1_1/config.json
# ./data/clean_model_proc_dates_0_2/config.json
# ./data/clean_model_proc_dates_1_2/config.json
# ./data/clean_model_proc_dates_0_3/config.json
# ./data/clean_model_proc_dates_1_3/config.json
# ./data/clean_model_proc_dates_0_4/config.json
# ./data/clean_model_proc_dates_1_4/config.json
# ./data/clean_model_note_drug_classes_0_0/config.json
# ./data/clean_model_note_drug_classes_1_0/config.json
# ./data/clean_model_note_drug_classes_0_1/config.json
# ./data/clean_model_note_drug_classes_1_1/config.json
# ./data/clean_model_note_drug_classes_0_2/config.json
# ./data/clean_model_note_drug_classes_1_2/config.json
# ./data/clean_model_note_drug_classes_0_3/config.json
# ./data/clean_model_note_drug_classes_1_3/config.json
# ./data/clean_model_note_drug_classes_0_4/config.json
# ./data/clean_model_note_drug_classes_1_4/config.json
# ./data/clean_model_neuro_note_count_0_0/config.json
# ./data/clean_model_neuro_note_count_1_0/config.json
# ./data/clean_model_neuro_note_count_0_1/config.json
# ./data/clean_model_neuro_note_count_1_1/config.json
# ./data/clean_model_neuro_note_count_0_2/config.json
# ./data/clean_model_neuro_note_count_1_2/config.json
# ./data/clean_model_neuro_note_count_0_3/config.json
# ./data/clean_model_neuro_note_count_1_3/config.json
# ./data/clean_model_neuro_note_count_0_4/config.json
# ./data/clean_model_neuro_note_count_1_4/config.json
# ./data/clean_model_status_epilepticus_0_0/config.json
# ./data/clean_model_status_epilepticus_1_0/config.json
# ./data/clean_model_status_epilepticus_0_1/config.json
# ./data/clean_model_status_epilepticus_1_1/config.json
# ./data/clean_model_status_epilepticus_0_2/config.json
# ./data/clean_model_status_epilepticus_1_2/config.json
# ./data/clean_model_status_epilepticus_0_3/config.json
# ./data/clean_model_status_epilepticus_1_3/config.json
# ./data/clean_model_status_epilepticus_0_4/config.json
# ./data/clean_model_status_epilepticus_1_4/config.json
# ./data/clean_model_total_inpatient_0_0/config.json
# ./data/clean_model_total_inpatient_1_0/config.json
# ./data/clean_model_total_inpatient_0_1/config.json
# ./data/clean_model_total_inpatient_1_1/config.json
# ./data/clean_model_total_inpatient_0_2/config.json
# ./data/clean_model_total_inpatient_1_2/config.json
# ./data/clean_model_total_inpatient_0_3/config.json
# ./data/clean_model_total_inpatient_1_3/config.json
# ./data/clean_model_total_inpatient_0_4/config.json
# ./data/clean_model_total_inpatient_1_4/config.json
# ./data/clean_model_inpatient_seizure_0_0/config.json
# ./data/clean_model_inpatient_seizure_1_0/config.json
# ./data/clean_model_inpatient_seizure_0_1/config.json
# ./data/clean_model_inpatient_seizure_1_1/config.json
# ./data/clean_model_inpatient_seizure_0_2/config.json
# ./data/clean_model_inpatient_seizure_1_2/config.json
# ./data/clean_model_inpatient_seizure_0_3/config.json
# ./data/clean_model_inpatient_seizure_1_3/config.json
# ./data/clean_model_inpatient_seizure_0_4/config.json
# ./data/clean_model_inpatient_seizure_1_4/config.json
# ./data/clean_model_seizure_icd_days_0_0/config.json
# ./data/clean_model_seizure_icd_days_1_0/config.json
# ./data/clean_model_seizure_icd_days_0_1/config.json
# ./data/clean_model_seizure_icd_days_1_1/config.json
# ./data/clean_model_seizure_icd_days_0_2/config.json
# ./data/clean_model_seizure_icd_days_1_2/config.json
# ./data/clean_model_seizure_icd_days_0_3/config.json
# ./data/clean_model_seizure_icd_days_1_3/config.json
# ./data/clean_model_seizure_icd_days_0_4/config.json
# ./data/clean_model_seizure_icd_days_1_4/config.json
# ./data/clean_model_seizure_visit_days_0_0/config.json
# ./data/clean_model_seizure_visit_days_1_0/config.json
# ./data/clean_model_seizure_visit_days_0_1/config.json
# ./data/clean_model_seizure_visit_days_1_1/config.json
# ./data/clean_model_seizure_visit_days_0_2/config.json
# ./data/clean_model_seizure_visit_days_1_2/config.json
# ./data/clean_model_seizure_visit_days_0_3/config.json
# ./data/clean_model_seizure_visit_days_1_3/config.json
# ./data/clean_model_seizure_visit_days_0_4/config.json
# ./data/clean_model_seizure_visit_days_1_4/config.json
# ./data/clean_model_structured_drug_class_0_0/config.json
# ./data/clean_model_structured_drug_class_1_0/config.json
# ./data/clean_model_structured_drug_class_0_1/config.json
# ./data/clean_model_structured_drug_class_1_1/config.json
# ./data/clean_model_structured_drug_class_0_2/config.json
# ./data/clean_model_structured_drug_class_1_2/config.json
# ./data/clean_model_structured_drug_class_0_3/config.json
# ./data/clean_model_structured_drug_class_1_3/config.json
# ./data/clean_model_structured_drug_class_0_4/config.json
# ./data/clean_model_structured_drug_class_1_4/config.json

# %%
import sys
original_stdout = sys.stdout

with open(f'./run_baseline_search.sh', 'w') as f:
    sys.stdout = f # Change the standard output to the file we created.
    print('#!/bin/bash')
    print(output[:-5])
    
sys.stdout = original_stdout
